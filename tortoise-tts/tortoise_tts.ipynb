# %% [markdown]
# Welcome to Tortoise! 🐢🐢🐢🐢
#
# Before you begin, I **strongly** recommend you turn on a GPU runtime.
#
# There's a reason this is called "Tortoise" - this model takes up to a minute to perform inference for a single sentence on a GPU. Expect waits on the order of hours on a CPU.

# %%
#first follow the instructions in the README.md file under Local Installation
# !pip3 install -r requirements.txt
# !python3 setup.py install
# Out:
# Requirement already satisfied: tqdm in /home/dyuthi/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 1)) (4.64.1)
# Requirement already satisfied: rotary_embedding_torch in /home/dyuthi/anaconda3/lib/python3.9/site-packages/rotary_embedding_torch-0.2.7-py3.9.egg (from -r requirements.txt (line 2)) (0.2.7)
# Collecting transformers==4.31.0
#   Downloading transformers-4.31.0-py3-none-any.whl (7.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 10.4 MB/s eta 0:00:00m eta 0:00:010:01:01
# Requirement already satisfied: tokenizers in /home/dyuthi/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 4)) (0.12.1)
# Requirement already satisfied: inflect in /home/dyuthi/anaconda3/lib/python3.9/site-packages/inflect-7.0.0-py3.9.egg (from -r requirements.txt (line 5)) (7.0.0)
# Requirement already satisfied: progressbar in /home/dyuthi/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 6)) (2.5)
# Collecting einops==0.4.1
#   Downloading einops-0.4.1-py3-none-any.whl (28 kB)
# Requirement already satisfied: unidecode in /home/dyuthi/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 8)) (1.2.0)
# Requirement already satisfied: scipy in /home/dyuthi/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 9)) (1.11.1)
# Collecting librosa==0.9.1
#   Downloading librosa-0.9.1-py3-none-any.whl (213 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 213.1/213.1 kB 5.2 MB/s eta 0:00:00 MB/s eta 0:00:01
# Collecting ffmpeg
#   Using cached ffmpeg-1.4-py3-none-any.whl
# Requirement already satisfied: numpy in /home/dyuthi/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 12)) (1.24.4)
# Requirement already satisfied: numba in /home/dyuthi/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 13)) (0.57.0)
# Requirement already satisfied: torchaudio in /home/dyuthi/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 14)) (2.0.2)
# Requirement already satisfied: threadpoolctl in /home/dyuthi/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 15)) (2.2.0)
# Requirement already satisfied: llvmlite in /home/dyuthi/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 16)) (0.40.1)
# Requirement already satisfied: appdirs in /home/dyuthi/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 17)) (1.4.4)
# Collecting nbconvert==5.3.1
#   Downloading nbconvert-5.3.1-py2.py3-none-any.whl (387 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 387.2/387.2 kB 9.5 MB/s eta 0:00:00 MB/s eta 0:00:01
# Collecting tornado==4.2
#   Downloading tornado-4.2.tar.gz (433 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 433.7/433.7 kB 9.7 MB/s eta 0:00:00-:--
#   Preparing metadata (setup.py) ... done
# Collecting pydantic==1.9.1
#   Downloading pydantic-1.9.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 7.7 MB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting deepspeed==0.8.3
#   Downloading deepspeed-0.8.3.tar.gz (765 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 765.4/765.4 kB 7.6 MB/s eta 0:00:00 MB/s eta 0:00:01
#   Preparing metadata (setup.py) ... done
# Collecting py-cpuinfo
#   Downloading py_cpuinfo-9.0.0-py3-none-any.whl (22 kB)
# Collecting hjson
#   Downloading hjson-3.1.0-py3-none-any.whl (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.0/54.0 kB 15.7 MB/s eta 0:00:00
# Requirement already satisfied: psutil in /home/dyuthi/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 24)) (5.9.0)
# Requirement already satisfied: filelock in /home/dyuthi/anaconda3/lib/python3.9/site-packages (from transformers==4.31.0->-r requirements.txt (line 3)) (3.6.0)
# Collecting safetensors>=0.3.1
#   Downloading safetensors-0.3.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 7.5 MB/s eta 0:00:008.0 MB/s eta 0:00:01
# Requirement already satisfied: regex!=2019.12.17 in /home/dyuthi/anaconda3/lib/python3.9/site-packages (from transformers==4.31.0->-r requirements.txt (line 3)) (2022.7.9)
# Requirement already satisfied: requests in /home/dyuthi/anaconda3/lib/python3.9/site-packages (from transformers==4.31.0->-r requirements.txt (line 3)) (2.31.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.14.1 in /home/dyuthi/anaconda3/lib/python3.9/site-packages (from transformers==4.31.0->-r requirements.txt (line 3)) (0.16.4)
# Requirement already satisfied: packaging>=20.0 in /home/dyuthi/anaconda3/lib/python3.9/site-packages (from transformers==4.31.0->-r requirements.txt (line 3)) (21.3)
# Requirement already satisfied: pyyaml>=5.1 in /home/dyuthi/anaconda3/lib/python3.9/site-packages (from transformers==4.31.0->-r requirements.txt (line 3)) (6.0)
# Collecting resampy>=0.2.2
#   Using cached resampy-0.4.2-py3-none-any.whl (3.1 MB)
# Requirement already satisfied: soundfile>=0.10.2 in /home/dyuthi/anaconda3/lib/python3.9/site-packages/soundfile-0.12.1-py3.9-linux-x86_64.egg (from librosa==0.9.1->-r requirements.txt (line 10)) (0.12.1)
# Requirement already satisfied: audioread>=2.1.5 in /home/dyuthi/anaconda3/lib/python3.9/site-packages/audioread-3.0.0-py3.9.egg (from librosa==0.9.1->-r requirements.txt (line 10)) (3.0.0)
# Requirement already satisfied: scikit-learn>=0.19.1 in /home/dyuthi/anaconda3/lib/python3.9/site-packages (from librosa==0.9.1->-r requirements.txt (line 10)) (1.3.0)
# Requirement already satisfied: joblib>=0.14 in /home/dyuthi/anaconda3/lib/python3.9/site-packages (from librosa==0.9.1->-r requirements.txt (line 10)) (1.3.1)
# Requirement already satisfied: pooch>=1.0 in /home/dyuthi/anaconda3/lib/python3.9/site-packages/pooch-1.6.0-py3.9.egg (from librosa==0.9.1->-r requirements.txt (line 10)) (1.6.0)
# Requirement already satisfied: decorator>=4.0.10 in /home/dyuthi/anaconda3/lib/python3.9/site-packages (from librosa==0.9.1->-r requirements.txt (line 10)) (5.1.1)
# Requirement already satisfied: entrypoints>=0.2.2 in /home/dyuthi/anaconda3/lib/python3.9/site-packages (from nbconvert==5.3.1->-r requirements.txt (line 18)) (0.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /home/dyuthi/anaconda3/lib/python3.9/site-packages (from nbconvert==5.3.1->-r requirements.txt (line 18)) (1.5.0)
# Requirement already satisfied: jinja2 in /home/dyuthi/anaconda3/lib/python3.9/site-packages (from nbconvert==5.3.1->-r requirements.txt (line 18)) (2.11.3)
# Requirement already satisfied: traitlets>=4.2 in /home/dyuthi/anaconda3/lib/python3.9/site-packages (from nbconvert==5.3.1->-r requirements.txt (line 18)) (5.1.1)
# Requirement already satisfied: nbformat>=4.4 in /home/dyuthi/anaconda3/lib/python3.9/site-packages (from nbconvert==5.3.1->-r requirements.txt (line 18)) (5.5.0)
# Requirement already satisfied: pygments in /home/dyuthi/anaconda3/lib/python3.9/site-packages (from nbconvert==5.3.1->-r requirements.txt (line 18)) (2.14.0)
# Requirement already satisfied: bleach in /home/dyuthi/anaconda3/lib/python3.9/site-packages (from nbconvert==5.3.1->-r requirements.txt (line 18)) (4.1.0)
# Requirement already satisfied: mistune>=0.7.4 in /home/dyuthi/anaconda3/lib/python3.9/site-packages (from nbconvert==5.3.1->-r requirements.txt (line 18)) (0.8.4)
# Requirement already satisfied: jupyter-core in /home/dyuthi/anaconda3/lib/python3.9/site-packages (from nbconvert==5.3.1->-r requirements.txt (line 18)) (4.11.1)
# Requirement already satisfied: testpath in /home/dyuthi/anaconda3/lib/python3.9/site-packages (from nbconvert==5.3.1->-r requirements.txt (line 18)) (0.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/dyuthi/anaconda3/lib/python3.9/site-packages (from pydantic==1.9.1->-r requirements.txt (line 20)) (4.7.1)
# Collecting ninja
#   Downloading ninja-1.11.1-py2.py3-none-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (145 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 146.0/146.0 kB 8.6 MB/s eta 0:00:00
# Requirement already satisfied: torch in /home/dyuthi/anaconda3/lib/python3.9/site-packages/torch-2.0.1-py3.9-linux-x86_64.egg (from deepspeed==0.8.3->-r requirements.txt (line 21)) (2.0.1)
# Requirement already satisfied: sympy in /home/dyuthi/anaconda3/lib/python3.9/site-packages (from torch->deepspeed==0.8.3->-r requirements.txt (line 21)) (1.10.1)
# Requirement already satisfied: networkx in /home/dyuthi/anaconda3/lib/python3.9/site-packages (from torch->deepspeed==0.8.3->-r requirements.txt (line 21)) (2.8.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /home/dyuthi/anaconda3/lib/python3.9/site-packages (from torch->deepspeed==0.8.3->-r requirements.txt (line 21)) (11.7.99)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /home/dyuthi/anaconda3/lib/python3.9/site-packages (from torch->deepspeed==0.8.3->-r requirements.txt (line 21)) (11.7.99)
# Requirement already satisfied: nvidia-cuda-cupti-cu11==11.7.101 in /home/dyuthi/anaconda3/lib/python3.9/site-packages (from torch->deepspeed==0.8.3->-r requirements.txt (line 21)) (11.7.101)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /home/dyuthi/anaconda3/lib/python3.9/site-packages (from torch->deepspeed==0.8.3->-r requirements.txt (line 21)) (8.5.0.96)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /home/dyuthi/anaconda3/lib/python3.9/site-packages (from torch->deepspeed==0.8.3->-r requirements.txt (line 21)) (11.10.3.66)
# Requirement already satisfied: nvidia-cufft-cu11==10.9.0.58 in /home/dyuthi/anaconda3/lib/python3.9/site-packages (from torch->deepspeed==0.8.3->-r requirements.txt (line 21)) (10.9.0.58)
# Requirement already satisfied: nvidia-curand-cu11==10.2.10.91 in /home/dyuthi/anaconda3/lib/python3.9/site-packages (from torch->deepspeed==0.8.3->-r requirements.txt (line 21)) (10.2.10.91)
# Requirement already satisfied: nvidia-cusolver-cu11==11.4.0.1 in /home/dyuthi/anaconda3/lib/python3.9/site-packages (from torch->deepspeed==0.8.3->-r requirements.txt (line 21)) (11.4.0.1)
# Requirement already satisfied: nvidia-cusparse-cu11==11.7.4.91 in /home/dyuthi/anaconda3/lib/python3.9/site-packages (from torch->deepspeed==0.8.3->-r requirements.txt (line 21)) (11.7.4.91)
# Requirement already satisfied: nvidia-nccl-cu11==2.14.3 in /home/dyuthi/anaconda3/lib/python3.9/site-packages (from torch->deepspeed==0.8.3->-r requirements.txt (line 21)) (2.14.3)
# Requirement already satisfied: nvidia-nvtx-cu11==11.7.91 in /home/dyuthi/anaconda3/lib/python3.9/site-packages (from torch->deepspeed==0.8.3->-r requirements.txt (line 21)) (11.7.91)
# Requirement already satisfied: triton==2.0.0 in /home/dyuthi/anaconda3/lib/python3.9/site-packages (from torch->deepspeed==0.8.3->-r requirements.txt (line 21)) (2.0.0)
# Requirement already satisfied: setuptools in /home/dyuthi/anaconda3/lib/python3.9/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch->deepspeed==0.8.3->-r requirements.txt (line 21)) (67.6.0)
# Requirement already satisfied: wheel in /home/dyuthi/anaconda3/lib/python3.9/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch->deepspeed==0.8.3->-r requirements.txt (line 21)) (0.37.1)
# Requirement already satisfied: cmake in /home/dyuthi/anaconda3/lib/python3.9/site-packages (from triton==2.0.0->torch->deepspeed==0.8.3->-r requirements.txt (line 21)) (3.27.1)
# Requirement already satisfied: lit in /home/dyuthi/anaconda3/lib/python3.9/site-packages (from triton==2.0.0->torch->deepspeed==0.8.3->-r requirements.txt (line 21)) (16.0.6)
# Requirement already satisfied: fsspec in /home/dyuthi/anaconda3/lib/python3.9/site-packages (from huggingface-hub<1.0,>=0.14.1->transformers==4.31.0->-r requirements.txt (line 3)) (2022.7.1)
# Requirement already satisfied: fastjsonschema in /home/dyuthi/anaconda3/lib/python3.9/site-packages (from nbformat>=4.4->nbconvert==5.3.1->-r requirements.txt (line 18)) (2.16.2)
# Requirement already satisfied: jsonschema>=2.6 in /home/dyuthi/anaconda3/lib/python3.9/site-packages (from nbformat>=4.4->nbconvert==5.3.1->-r requirements.txt (line 18)) (4.16.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/dyuthi/anaconda3/lib/python3.9/site-packages (from packaging>=20.0->transformers==4.31.0->-r requirements.txt (line 3)) (3.0.9)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/dyuthi/anaconda3/lib/python3.9/site-packages (from requests->transformers==4.31.0->-r requirements.txt (line 3)) (1.26.11)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/dyuthi/anaconda3/lib/python3.9/site-packages (from requests->transformers==4.31.0->-r requirements.txt (line 3)) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/dyuthi/anaconda3/lib/python3.9/site-packages (from requests->transformers==4.31.0->-r requirements.txt (line 3)) (2022.9.14)
# Requirement already satisfied: idna<4,>=2.5 in /home/dyuthi/anaconda3/lib/python3.9/site-packages (from requests->transformers==4.31.0->-r requirements.txt (line 3)) (3.3)
# Requirement already satisfied: cffi>=1.0 in /home/dyuthi/anaconda3/lib/python3.9/site-packages (from soundfile>=0.10.2->librosa==0.9.1->-r requirements.txt (line 10)) (1.15.1)
# Requirement already satisfied: six>=1.9.0 in /home/dyuthi/anaconda3/lib/python3.9/site-packages (from bleach->nbconvert==5.3.1->-r requirements.txt (line 18)) (1.16.0)
# Requirement already satisfied: webencodings in /home/dyuthi/anaconda3/lib/python3.9/site-packages (from bleach->nbconvert==5.3.1->-r requirements.txt (line 18)) (0.5.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /home/dyuthi/anaconda3/lib/python3.9/site-packages (from jinja2->nbconvert==5.3.1->-r requirements.txt (line 18)) (2.0.1)
# Requirement already satisfied: pycparser in /home/dyuthi/anaconda3/lib/python3.9/site-packages (from cffi>=1.0->soundfile>=0.10.2->librosa==0.9.1->-r requirements.txt (line 10)) (2.21)
# Requirement already satisfied: attrs>=17.4.0 in /home/dyuthi/anaconda3/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat>=4.4->nbconvert==5.3.1->-r requirements.txt (line 18)) (21.4.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /home/dyuthi/anaconda3/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat>=4.4->nbconvert==5.3.1->-r requirements.txt (line 18)) (0.18.0)
# Requirement already satisfied: mpmath>=0.19 in /home/dyuthi/anaconda3/lib/python3.9/site-packages (from sympy->torch->deepspeed==0.8.3->-r requirements.txt (line 21)) (1.2.1)
# Building wheels for collected packages: tornado, deepspeed
#   Building wheel for tornado (setup.py) ... done
#   Created wheel for tornado: filename=tornado-4.2-cp39-cp39-linux_x86_64.whl size=376706 sha256=3a182a100e1413546e2f023d78bdadeee7ef7237b05a9ed31603e3c5b600e160
#   Stored in directory: /home/dyuthi/.cache/pip/wheels/ba/58/c1/d2b40a52224be723109c92ae873219285b674a0bc8d0555488
#   Building wheel for deepspeed (setup.py) ... done
#   Created wheel for deepspeed: filename=deepspeed-0.8.3-py3-none-any.whl size=776382 sha256=c1935a222e5b1ca598b1edbd9232fc0a119c415040bdb8e8d578097b0cc9b066
#   Stored in directory: /home/dyuthi/.cache/pip/wheels/f8/ea/8f/0768328ba436ed66f602d8d3b809624448c9eb627434176d04
# Successfully built tornado deepspeed
# Installing collected packages: tornado, safetensors, py-cpuinfo, ninja, hjson, ffmpeg, einops, pydantic, resampy, transformers, nbconvert, librosa, deepspeed
#   Attempting uninstall: tornado
#     Found existing installation: tornado 6.1
#     Uninstalling tornado-6.1:
#       Successfully uninstalled tornado-6.1
#   Attempting uninstall: einops
#     Found existing installation: einops 0.7.0rc1
#     Uninstalling einops-0.7.0rc1:
#       Successfully uninstalled einops-0.7.0rc1
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 2.1.1
#     Uninstalling pydantic-2.1.1:
#       Successfully uninstalled pydantic-2.1.1
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.19.0
#     Uninstalling transformers-4.19.0:
#       Successfully uninstalled transformers-4.19.0
#   Attempting uninstall: nbconvert
#     Found existing installation: nbconvert 6.4.4
#     Uninstalling nbconvert-6.4.4:
#       Successfully uninstalled nbconvert-6.4.4
#   Attempting uninstall: librosa
#     Found existing installation: librosa 0.10.0.post2
#     Uninstalling librosa-0.10.0.post2:
#       Successfully uninstalled librosa-0.10.0.post2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# spyder 5.3.3 requires pyqt5<5.16, which is not installed.
# spyder 5.3.3 requires pyqtwebengine<5.16, which is not installed.
# anaconda-project 0.11.1 requires ruamel-yaml, which is not installed.
# streamlit 1.25.0 requires tornado<7,>=6.0.3, but you have tornado 4.2 which is incompatible.
# notebook 6.4.12 requires tornado>=6.1, but you have tornado 4.2 which is incompatible.
# jupyterlab 3.4.4 requires tornado>=6.1.0, but you have tornado 4.2 which is incompatible.
# jupyter-server 1.18.1 requires nbconvert>=6.4.4, but you have nbconvert 5.3.1 which is incompatible.
# jupyter-server 1.18.1 requires tornado>=6.1.0, but you have tornado 4.2 which is incompatible.
# jupyter-client 7.3.4 requires tornado>=6.0, but you have tornado 4.2 which is incompatible.
# ipykernel 6.15.2 requires tornado>=6.1, but you have tornado 4.2 which is incompatible.
# distributed 2022.7.0 requires tornado<6.2,>=6.0.3, but you have tornado 4.2 which is incompatible.
# bokeh 2.4.3 requires tornado>=5.1, but you have tornado 4.2 which is incompatible.
# Successfully installed deepspeed-0.8.3 einops-0.4.1 ffmpeg-1.4 hjson-3.1.0 librosa-0.9.1 nbconvert-5.3.1 ninja-1.11.1 py-cpuinfo-9.0.0 pydantic-1.9.1 resampy-0.4.2 safetensors-0.3.2 tornado-4.2 transformers-4.31.0

# %%
# Imports used through the rest of the notebook.
import torch
import torchaudio
import torch.nn as nn
import torch.nn.functional as F

import IPython

from tortoise.api import TextToSpeech
from tortoise.utils.audio import load_audio, load_voice, load_voices

# This will download all the models used by Tortoise from the HF hub.
# tts = TextToSpeech()
# If you want to use deepspeed the pass use_deepspeed=True nearly 2x faster than normal
tts = TextToSpeech(use_deepspeed=True, kv_cache=True)

# %%
# This is the text that will be spoken.
text = "Joining two modalities results in a surprising increase in generalization! What would happen if we combined them all?"
# text = "hello everyone"
# Here's something for the poetically inclined.. (set text=)
"""
Then took the other, as just as fair,
And having perhaps the better claim,
Because it was grassy and wanted wear;
Though as for that the passing there
Had worn them really about the same,"""

# Pick a "preset mode" to determine quality. Options: {"ultra_fast", "fast" (default), "standard", "high_quality"}. See docs in api.py
preset = "ultra_fast"

# %%
# Tortoise will attempt to mimic voices you provide. It comes pre-packaged
# with some voices you might recognize.

# Let's list all the voices available. These are just some random clips I've gathered
# from the internet as well as a few voices from the training dataset.
# Feel free to add your own clips to the voices/ folder.
# %ls tortoise/voices

IPython.display.Audio('tortoise/voices/tom/1.wav')
# Out:
# angie/                freeman/  pat/           train_daws/      train_mouse/
# applejack/            geralt/   pat2/          train_dotrice/   weaver/
# cond_latent_example/  halle/    rainbow/       train_dreams/    william/
# daniel/               jlaw/     snakes/        train_empire/
# deniro/               lj/       tim_reynolds/  train_grace/
# dyuthi/               mol/      tom/           train_kennard/
# emma/                 myself/   train_atkins/  train_lescault/
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Pick one of the voices from the output above
voice = 'dyuthi'

# Load it and send it through Tortoise.
voice_samples, conditioning_latents = load_voice(voice)

# %%
gen = tts.tts_with_preset(text, voice_samples=voice_samples, conditioning_latents=conditioning_latents, 
                          preset=preset)
torchaudio.save('generated.wav', gen.squeeze(0).cpu(), 24000)
IPython.display.Audio('generated.wav')
# Out:
# Generating autoregressive samples..
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████| 16/16 [02:53<00:00, 10.82s/it]
# Computing best candidates using CLVP
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████| 16/16 [00:17<00:00,  1.08s/it]
# Transforming autoregressive outputs into audio..
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████| 30/30 [00:39<00:00,  1.32s/it]
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Tortoise can also generate speech using a random voice. The voice changes each time you execute this!
# (Note: random voices can be prone to strange utterances)
gen = tts.tts_with_preset(text, voice_samples=None, conditioning_latents=None, preset=preset)
torchaudio.save('generated.wav', gen.squeeze(0).cpu(), 24000)
IPython.display.Audio('generated.wav')

# %%
# You can also combine conditioning voices. Combining voices produces a new voice
# with traits from all the parents.
#
# Lets see what it would sound like if Picard and Kirk had a kid with a penchant for philosophy:
voice_samples, conditioning_latents = load_voices(['pat', 'william'])

gen = tts.tts_with_preset("They used to say that if man was meant to fly, he’d have wings. But he did fly. He discovered he had to.", 
                          voice_samples=None, conditioning_latents=None, preset=preset)
torchaudio.save('captain_kirkard.wav', gen.squeeze(0).cpu(), 24000)
IPython.display.Audio('captain_kirkard.wav')

# %%
del tts  # Will break other cells, but necessary to conserve RAM if you want to run this cell.

# Tortoise comes with some scripts that does a lot of the lifting for you. For example,
# read.py will read a text file for you.
# !python3 tortoise/read.py --voice=train_atkins --textfile=tortoise/data/riding_hood.txt --preset=ultra_fast --output_path=.

IPython.display.Audio('train_atkins/combined.wav')
# This will take awhile..
